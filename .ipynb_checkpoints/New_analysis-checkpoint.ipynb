# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns

# %%
def get_ref():
    
    clash_df = pd.read_csv("analysis/reference-clashes.csv", index_col = 0)
    cor_df = pd.read_csv("analysis/reference-correlation.csv", index_col = 0)
    ref_df = clash_df.join(cor_df["correlation"])
    return ref_df

def make_df_list(run):
    clash_3J95 = pd.read_csv(("analysis/{}/3J95_clashes.csv").format(run), index_col = "structure")
    clash_3J96 = pd.read_csv(("analysis/{}/3J96_clashes.csv").format(run), index_col = "structure")
    clash_5GRS = pd.read_csv(("analysis/{}/5GRS_clashes.csv").format(run), index_col = "structure")
    clash_5HNY = pd.read_csv(("analysis/{}/5HNY_clashes.csv").format(run), index_col = "structure")
    clash_5WCB = pd.read_csv(("analysis/{}/5WCB_clashes.csv").format(run), index_col = "structure")
    clash_6ACG = pd.read_csv(("analysis/{}/6ACG_clashes.csv").format(run), index_col = "structure")
    clash_6AHF = pd.read_csv(("analysis/{}/6AHF_clashes.csv").format(run), index_col = "structure")
    clash_6C06 = pd.read_csv(("analysis/{}/6C06_clashes.csv").format(run), index_col = "structure")
    clash_6C3P = pd.read_csv(("analysis/{}/6C3P_clashes.csv").format(run), index_col = "structure")
    clash_6ENY = pd.read_csv(("analysis/{}/6ENY_clashes.csv").format(run), index_col = "structure")
    clash_6IRF = pd.read_csv(("analysis/{}/6IRF_clashes.csv").format(run), index_col = "structure")
    clash_6N1Q = pd.read_csv(("analysis/{}/6N1Q_clashes.csv").format(run), index_col = "structure")
    clash_6N7G = pd.read_csv(("analysis/{}/6N7G_clashes.csv").format(run), index_col = "structure")
    clash_6N8T = pd.read_csv(("analysis/{}/6N8T_clashes.csv").format(run), index_col = "structure")
    clash_6N8Z = pd.read_csv(("analysis/{}/6N8Z_clashes.csv").format(run), index_col = "structure")
    clash_6R7I = pd.read_csv(("analysis/{}/6R7I_clashes.csv").format(run), index_col = "structure")
    clash_6UBY = pd.read_csv(("analysis/{}/6UBY_clashes.csv").format(run), index_col = "structure")
    clash_6UC0 = pd.read_csv(("analysis/{}/6UC0_clashes.csv").format(run), index_col = "structure")
    
    df_3J95 = clash_3J95.join(pd.read_csv(("analysis/{}/3J95_correlation.csv").format(run), index_col = "structure")["correlation"])
    df_3J96 = clash_3J96.join(pd.read_csv(("analysis/{}/3J96_correlation.csv").format(run), index_col = "structure")["correlation"])
    df_5GRS = clash_5GRS.join(pd.read_csv(("analysis/{}/5GRS_correlation.csv").format(run), index_col = "structure")["correlation"])
    df_5HNY = clash_5HNY.join(pd.read_csv(("analysis/{}/5HNY_correlation.csv").format(run), index_col = "structure")["correlation"])
    df_5WCB = clash_5WCB.join(pd.read_csv(("analysis/{}/5WCB_correlation.csv").format(run), index_col = "structure")["correlation"])
    df_6ACG = clash_6ACG.join(pd.read_csv(("analysis/{}/6ACG_correlation.csv").format(run), index_col = "structure")["correlation"])
    df_6AHF = clash_6AHF.join(pd.read_csv(("analysis/{}/6AHF_correlation.csv").format(run), index_col = "structure")["correlation"])
    df_6C06 = clash_6C06.join(pd.read_csv(("analysis/{}/6C06_correlation.csv").format(run), index_col = "structure")["correlation"])
    df_6C3P = clash_6C3P.join(pd.read_csv(("analysis/{}/6C3P_correlation.csv").format(run), index_col = "structure")["correlation"])
    df_6ENY = clash_6ENY.join(pd.read_csv(("analysis/{}/6ENY_correlation.csv").format(run), index_col = "structure")["correlation"])
    df_6IRF = clash_6IRF.join(pd.read_csv(("analysis/{}/6IRF_correlation.csv").format(run), index_col = "structure")["correlation"])
    df_6N1Q = clash_6N1Q.join(pd.read_csv(("analysis/{}/6N1Q_correlation.csv").format(run), index_col = "structure")["correlation"])
    df_6N7G = clash_6N7G.join(pd.read_csv(("analysis/{}/6N7G_correlation.csv").format(run), index_col = "structure")["correlation"])
    df_6N8T = clash_6N8T.join(pd.read_csv(("analysis/{}/6N8T_correlation.csv").format(run), index_col = "structure")["correlation"])
    df_6N8Z = clash_6N8Z.join(pd.read_csv(("analysis/{}/6N8Z_correlation.csv").format(run), index_col = "structure")["correlation"])
    df_6R7I = clash_6R7I.join(pd.read_csv(("analysis/{}/6R7I_correlation.csv").format(run), index_col = "structure")["correlation"])
    df_6UBY = clash_6UBY.join(pd.read_csv(("analysis/{}/6UBY_correlation.csv").format(run), index_col = "structure")["correlation"])
    df_6UC0 = clash_6UC0.join(pd.read_csv(("analysis/{}/6UC0_correlation.csv").format(run), index_col = "structure")["correlation"])
    
    
    df_list = [
        df_3J95,
        df_3J96,
        df_5GRS,
        df_5HNY,
        df_5WCB,
        df_6ACG,
        df_6AHF,
        df_6C06,
        df_6C3P,
        df_6ENY,
        df_6IRF,
        df_6N1Q,
        df_6N7G,
        df_6N8T,
        df_6N8Z,
        df_6R7I,
        df_6UBY,
        df_6UC0,
    ]
    
    return df_list

all_runs = [
    "analysis_run-no-ambig",
    "analysis_run-with-ambig",
    "analysis_run-general-ambig",
    "analysis_run-no-ambig-0.05-expand",
    "analysis_run-with-ambig-0.05-expand",
    "analysis_run-general-ambig-0.05-expand",
    "analysis_run-no-ambig-0.2-expand",
    "analysis_run-with-ambig-0.2-expand",
    "analysis_run-general-ambig-0.2-expand"
    
]

# %%
def make_succes_df_list(run):    
    for i, run_from_all in enumerate(all_runs):
        run_dict = {}
        df_list = make_df_list(run_from_all)
        run_dict[run_from_all] = {}
        for df in df_list:
            run_dict[run_from_all][df.index[0][:4]] = df.shape[0]
            #print("complex {} resulted in {} models".format(df.index[0][0:4],df.shape[0]))
        if i == 0:
            all_df = pd.DataFrame.from_dict(run_dict)
        else:
            temp_df = pd.DataFrame.from_dict(run_dict)
            all_df = pd.concat([all_df,temp_df], axis = 1)

    succes_list = []        
    for index in all_df.index:
        if all_df.loc[index].sum() == 450:
            succes_list.append(index)


    df_list = make_df_list(run)
    succes_df_list = []
    for df in df_list:
        if df.index[0][:4] in succes_list:
            succes_df_list.append(df)

    return succes_df_list, succes_list

# %%
new_df_dict = {}
for run in all_runs:
    new_df_dict[run] = {}
    succes_df_list, succes_list = make_succes_df_list(run)
    for compl in succes_df_list:
        curr_sorted = compl.sort_values("HADDOCK-score")
        new_df_dict[run][compl.index[0][:4]] = pd.DataFrame(curr_sorted.iloc[:4])
        
print(succes_list)
# Out:
# ['3J95', '3J96', '5GRS', '5HNY', '5WCB', '6ACG', '6IRF', '6N1Q', '6N7G', '6R7I', '6UC0']

# %%
ref_df = get_ref()
analyzer = "correlation"
fig, ax = plt.subplots(figsize=(5,5))
lst = [0, 3, 6, 9, 12, 15]
column = -1

full_df = pd.DataFrame()
for i, compl in enumerate(succes_list):
        
    run_dict = {}
    for j, run in enumerate(new_df_dict):
        run_dict = {}
        curr = new_df_dict[run][compl]
        run_dict[run] = curr[analyzer]
    
        if j == 0:
            df = pd.DataFrame.from_dict(run_dict).reset_index().drop("structure", axis = 1)
        else:
            add_df = pd.DataFrame.from_dict(run_dict).reset_index().drop("structure", axis = 1)
            df = pd.concat([df, add_df], axis = 1)
    if analyzer == "atomic-clashes":
        analyse = "clashes"
    else:
        analyse = analyzer
#     add_df = pd.Series(ref_df.loc[compl,analyse], name = "Ref")
#     df = pd.concat([df, add_df], axis = 1)
#     df = df.sub(ref_df.loc[compl,analyse])

    
    full_df = pd.concat([full_df, df])
    
full_df
plot = sns.boxplot(data = full_df)
plot.set_xticklabels(plot.get_xticklabels(), rotation=45, ha="right")
# plot.set_title("Refinement Protocol")

#     if row == 0:
plot.set_ylabel("Δ Cross-Correlation")
# plt.setp(plot, ylim=[-0.04, 0.002])
#     if column < 3:
# plot.bar(x,y)
# plot.set_xticks(x)
plot.set_xticklabels(["norestraints", "specific-restraints", 
                 "general-restrains", "no-restraints-0.05-expand", 
                 "specific-restraints-0.05-expand", "general-restraints-0.05-expand",
                 "no-restraints-0.2-expand", "specific-restraints-0.2-expand",
                 "general-restraints-0.2-expand", "reference"])

plt.tight_layout()
# plt.savefig("box-delta-correlation", dpi = 100)

# %%
def get_water_df_list(run):
    df_3J95 = pd.read_csv(("analysis/{}/water/3J95_correlation.csv").format(run), index_col = "structure")
    df_3J96 = pd.read_csv(("analysis/{}/water/3J96_correlation.csv").format(run), index_col = "structure")
    df_5GRS = pd.read_csv(("analysis/{}/water/5GRS_correlation.csv").format(run), index_col = "structure")
    df_5HNY = pd.read_csv(("analysis/{}/water/5HNY_correlation.csv").format(run), index_col = "structure")
    df_5WCB = pd.read_csv(("analysis/{}/water/5WCB_correlation.csv").format(run), index_col = "structure")
    df_6ACG = pd.read_csv(("analysis/{}/water/6ACG_correlation.csv").format(run), index_col = "structure")
    df_6AHF = pd.read_csv(("analysis/{}/water/6AHF_correlation.csv").format(run), index_col = "structure")
    df_6C06 = pd.read_csv(("analysis/{}/water/6C06_correlation.csv").format(run), index_col = "structure")
    df_6C3P = pd.read_csv(("analysis/{}/water/6C3P_correlation.csv").format(run), index_col = "structure")
    df_6ENY = pd.read_csv(("analysis/{}/water/6ENY_correlation.csv").format(run), index_col = "structure")
    df_6IRF = pd.read_csv(("analysis/{}/water/6IRF_correlation.csv").format(run), index_col = "structure")
    df_6N1Q = pd.read_csv(("analysis/{}/water/6N1Q_correlation.csv").format(run), index_col = "structure")
    df_6N7G = pd.read_csv(("analysis/{}/water/6N7G_correlation.csv").format(run), index_col = "structure")
    df_6N8T = pd.read_csv(("analysis/{}/water/6N8T_correlation.csv").format(run), index_col = "structure")
    df_6N8Z = pd.read_csv(("analysis/{}/water/6N8Z_correlation.csv").format(run), index_col = "structure")
    df_6R7I = pd.read_csv(("analysis/{}/water/6R7I_correlation.csv").format(run), index_col = "structure")
    df_6UBY = pd.read_csv(("analysis/{}/water/6UBY_correlation.csv").format(run), index_col = "structure")
    df_6UC0 = pd.read_csv(("analysis/{}/water/6UC0_correlation.csv").format(run), index_col = "structure")
    
    df_list = [
        df_3J95,
        df_3J96,
        df_5GRS,
        df_5HNY,
        df_5WCB,
        df_6ACG,
        df_6AHF,
        df_6C06,
        df_6C3P,
        df_6ENY,
        df_6IRF,
        df_6N1Q,
        df_6N7G,
        df_6N8T,
        df_6N8Z,
        df_6R7I,
        df_6UBY,
        df_6UC0,
    ]
    
    return df_list

# %%
df_list = get_water_df_list("analysis_run-general-ambig")

all_dict = {}
for run in all_runs:
    all_dict[run] = {}
    df_list = get_water_df_list(run)
    for df in df_list:
        compl = df.index[0][0:4]
        if compl in succes_list:
            all_dict[run][compl] = df.sort_values("HADDOCK-score").iloc[0:4]

# %%
analyzer = "correlation"
fig, ax = plt.subplots(figsize=(5,5))

full_water_df = pd.DataFrame()
for i, compl in enumerate(succes_list):
        
    run_dict = {}
    for j, run in enumerate(all_dict):
        run_dict = {}
        curr = new_df_dict[run][compl]
        run_dict[run] = curr[analyzer]
    
        if j == 0:
            df = pd.DataFrame.from_dict(run_dict).reset_index().drop("structure", axis = 1)
        else:
            add_df = pd.DataFrame.from_dict(run_dict).reset_index().drop("structure", axis = 1)
            df = pd.concat([df, add_df], axis = 1)
    if analyzer == "atomic-clashes":
        analyse = "clashes"
    else:
        analyse = analyzer
#     add_df = pd.Series(ref_df.loc[compl,analyse], name = "Ref")
#     df = pd.concat([df, add_df], axis = 1)
#     df = df.sub(ref_df.loc[compl,analyse])

    
    full_water_df = pd.concat([full_water_df, df])
    
plot = sns.boxplot(data = full_water_df)
plot.set_xticklabels(plot.get_xticklabels(), rotation=45, ha="right")
# plot.set_title("Refinement Protocol")

#     if row == 0:
plot.set_ylabel("Δ Cross-Correlation")
# plt.setp(plot, ylim=[-0.04, 0.002])
#     if column < 3:
# plot.bar(x,y)
# plot.set_xticks(x)
plot.set_xticklabels(["no-restraints", "specific-restraints", 
                 "general-restrains", "no-restraints-0.05-expand", 
                 "specific-restraints-0.05-expand", "general-restraints-0.05-expand",
                 "no-restraints-0.2-expand", "specific-restraints-0.2-expand",
                 "general-restraints-0.2-expand", "reference"])

plt.tight_layout()
# plt.savefig("box-delta-correlation", dpi = 100)

# %%
# full_water_df.iloc[:,0:3]

analyzer = "correlation"
df_water = pd.DataFrame()
for run in all_dict:
    run = all_dict[run]
    for i, struct in enumerate(run):
        struct = run[struct]
        if i == 0:
            df = pd.DataFrame.from_dict(struct)
        else:
            add_df = pd.DataFrame.from_dict(struct)
            df = pd.concat([df, add_df])
    df = df.reset_index()
    df_water = pd.concat([df_water,df[analyzer]], axis=1)

comp_no_expand = pd.concat([full_df.iloc[:,0].reset_index().drop("index", axis =1), df_water.iloc[:,0]], axis = 1)
sns.boxplot(data=comp_no_expand)
plt.show()

# %%
em_run_names = ["analysis_run-no-ambig-EM", "analysis_run-with-ambig-EM", "analysis_run-general-ambig-EM"]

succes_list = []
em_run_results = make_df_list(em_run_names[1])
for run in em_run_results:
    if len(run) == 50:
        succes_list.append(run.index[0][:4])
# em_run_results[0].sort_values("HADDOCK-score")
# Out:
#              HADDOCK-score  atomic-clashes  correlation
# structure
# 3J95_1.pdb     -3210.95710               0       0.9289
# 3J95_10.pdb    -3188.90640               3       0.9276
# 3J95_11.pdb    -2958.06020               0       0.9263
# 3J95_12.pdb    -3184.66340               2       0.9274
# 3J95_13.pdb    -3170.47690               0       0.9280
# 3J95_14.pdb    -3019.19860               1       0.9263
# 3J95_15.pdb    -3267.29530               0       0.9259
# 3J95_16.pdb    -3018.14520               2       0.9254
# 3J95_17.pdb    -3170.79820               1       0.9292
# 3J95_18.pdb    -3022.16940               0       0.9271
# 3J95_19.pdb    -3380.10100               1       0.9273
# 3J95_2.pdb     -3085.38070               1       0.9286
# 3J95_20.pdb    -3121.17440               2       0.9266
# 3J95_21.pdb    -1502.01170               3       0.9283
# 3J95_22.pdb    -2932.97720               0       0.9257
# 3J95_23.pdb    -2968.54130               1       0.9266
# 3J95_24.pdb    -3041.39360               0       0.9251
# 3J95_25.pdb    -3255.71680               2       0.9295
# 3J95_26.pdb    -3166.60030               2       0.9262
# 3J95_27.pdb    -3338.31180               1       0.9274
# 3J95_28.pdb    -3251.15560               0       0.9270
# 3J95_29.pdb    -3063.35830               0       0.9268
# 3J95_3.pdb     -2931.37070               0       0.9253
# 3J95_30.pdb    -3103.27230               3       0.9274
# 3J95_31.pdb    -2838.05220               0       0.9283
# 3J95_32.pdb    -3116.37690               0       0.9271
# 3J95_33.pdb    -3229.76150               1       0.9259
# 3J95_34.pdb    -2988.27310               0       0.9250
# 3J95_35.pdb    -3307.45218               1       0.9270
# 3J95_36.pdb    -2809.64270               0       0.9279
# 3J95_37.pdb    -3253.61510               1       0.9282
# 3J95_38.pdb    -3231.41940               2       0.9290
# 3J95_39.pdb    -2967.30290               0       0.9274
# 3J95_4.pdb     -3409.59910               2       0.9283
# 3J95_40.pdb    -3293.47960               1       0.9268
# 3J95_41.pdb    -3067.66640               0       0.9293
# 3J95_42.pdb    -2899.21590               0       0.9279
# 3J95_43.pdb    -3243.59000               0       0.9280
# 3J95_44.pdb    -3216.66520               2       0.9291
# 3J95_45.pdb    -3339.90880               1       0.9281
# 3J95_46.pdb    -3150.41120               1       0.9243
# 3J95_47.pdb    -3202.68600               2       0.9297
# 3J95_48.pdb    -3156.49680               1       0.9276
# 3J95_49.pdb    -3264.43570               2       0.9317
# 3J95_5.pdb     -3097.33730               3       0.9258
# 3J95_50.pdb    -3155.13020               0       0.9312
# 3J95_6.pdb     -3122.15100               0       0.9287
# 3J95_7.pdb     -3166.26600               1       0.9281
# 3J95_8.pdb     -3308.13020               1       0.9270
# 6ENY_42.pdb      199.97980              14       0.8831
# 6ENY_43.pdb       77.53972              14       0.8840
# 6ENY_44.pdb      235.35343              14       0.8828
# 6ENY_45.pdb      216.41601              12       0.8841
# 6ENY_46.pdb    -1294.67370               5       0.8813
# 6ENY_47.pdb      326.62620              14       0.8814
# 6ENY_48.pdb      193.73128              14       0.8842
# 6ENY_49.pdb      242.32490              14       0.8835
# 6ENY_5.pdb       236.01840              14       0.8824
# 6ENY_50.pdb      159.28364              16       0.8829
# 6ENY_6.pdb       161.24629              13       0.8827
# 6ENY_7.pdb       407.94650              15       0.8355
# 6ENY_8.pdb       242.30499              14       0.8820
# 6ENY_9.pdb         1.64424              14       0.8847
#              HADDOCK-score  atomic-clashes  correlation
# structure
# 6N1Q_1.pdb       2930.7031              33       0.8873
# 6N1Q_10.pdb      4413.1997              43       0.8929
# 6N1Q_11.pdb      4479.3614              44       0.8868
# 6N1Q_12.pdb      4514.6388              43       0.8999
# 6N1Q_13.pdb      4762.7673              45       0.8964
# 6N1Q_14.pdb      1275.8679              22       0.8893
# 6N1Q_15.pdb      4486.2799              43       0.9018
# 6N1Q_16.pdb      4561.6136              46       0.8909
# 6N1Q_17.pdb      1410.0812              24       0.8920
# 6N1Q_18.pdb      4848.1123              44       0.8940
# 6N1Q_19.pdb      4447.1966              43       0.8972
# 6N1Q_2.pdb       4429.0343              43       0.8925
# 6N1Q_20.pdb      1120.1020              21       0.8925
# 6N1Q_21.pdb      4806.2917              45       0.8962
# 6N1Q_22.pdb      4538.9708              43       0.9013
# 6N1Q_23.pdb      4818.7862              44       0.8981
# 6N1Q_24.pdb      4713.9283              44       0.8966
# 6N1Q_25.pdb      4299.5486              43       0.8897
# 6N1Q_26.pdb      4618.9590              44       0.8952
# 6N1Q_27.pdb      4443.9598              43       0.8941
# 6N1Q_28.pdb      4536.9452              43       0.8977
# 6N1Q_29.pdb      4836.0445              44       0.8861
# 6N1Q_3.pdb       4759.2183              44       0.8948
# 6N1Q_30.pdb      2767.3148              34       0.8998
# 6N1Q_31.pdb      4612.2989              45       0.8964
# 6N1Q_32.pdb      1795.1728              23       0.8832
# 6N1Q_33.pdb      2818.8504              34       0.8965
# 6N1Q_34.pdb      3046.4580              34       0.8956
# 6N1Q_35.pdb      2861.2629              33       0.8959
# 6N1Q_36.pdb      4521.7749              43       0.8866
# 6N1Q_37.pdb      5072.4389              44       0.8962
# 6N1Q_38.pdb      4847.6369              44       0.8882
# 6N1Q_39.pdb      1685.1585              22       0.8831
# 6N1Q_4.pdb       4535.8904              44       0.9025
# 6N1Q_40.pdb      4444.9578              43       0.8968
# 6N1Q_41.pdb      4595.3436              45       0.9042
# 6N1Q_42.pdb      2860.0299              35       0.8938
# 6N1Q_43.pdb      4606.1820              44       0.9085
# 6N1Q_44.pdb      2767.0636              33       0.8961
# 6N1Q_45.pdb      2726.6592              33       0.8943
# 6N1Q_46.pdb      4574.7005              44       0.8982
# 6N1Q_47.pdb      3046.1130              33       0.8933
# 6N1Q_48.pdb      4601.8325              46       0.9084
#              HADDOCK-score  atomic-clashes  correlation
# structure
# 6N8T_1.pdb     -5450.50180              13       0.8778
# 6N8T_10.pdb    -5632.68740              12       0.8759
# 6N8T_11.pdb    -5272.71100              17       0.8727
# 6N8T_12.pdb    -5157.39465              26       0.8836
# 6N8T_13.pdb    -5406.54450              13       0.8754
# 6N8T_14.pdb    -5603.39980              15       0.8751
# 6N8T_15.pdb    -5672.08870              12       0.8760
# 6N8T_16.pdb    -5157.39465              26       0.8836
# 6N8T_17.pdb    -5157.39465              26       0.8836
# 6N8T_18.pdb    -5323.97070              12       0.8734
# 6N8T_19.pdb    -5157.39465              26       0.8836
# 6N8T_2.pdb     -5300.07680              13       0.8737
# 6N8T_20.pdb    -5447.56820              12       0.8788
# 6N8T_21.pdb    -5233.17730              14       0.8723
# 6N8T_22.pdb    -5157.39465              26       0.8836
# 6N8T_23.pdb    -5237.88240              18       0.8749
# 6N8T_24.pdb    -5154.80750              21       0.8754
# 6N8T_25.pdb    -4780.92390              11       0.8723
# 6N8T_26.pdb    -5157.39465              26       0.8836
# 6N8T_27.pdb    -5094.58720              11       0.8714
# 6N8T_28.pdb    -5067.92190              11       0.8742
# 6N8T_29.pdb    -5197.08520              12       0.8740
# 6N8T_3.pdb     -5183.41140              14       0.8789
# 6N8T_30.pdb    -4904.00870              12       0.8783
# 6N8T_31.pdb    -5548.55020              13       0.8803
# 6N8T_32.pdb    -4996.75290              17       0.8713
# 6N8T_33.pdb    -5002.71150              12       0.8729
# 6N8T_34.pdb    -5304.88480              12       0.8744
# 6N8T_35.pdb    -4740.62350              11       0.8644
# 6N8T_36.pdb    -4430.05590               6       0.8735
# 6N8T_37.pdb    -5483.11740              19       0.8793
# 6N8T_38.pdb    -5611.86700              18       0.8752
# 6N8T_39.pdb    -4895.42830              15       0.8764
# 6N8T_4.pdb     -5079.63530              15       0.8752
# 6N8T_40.pdb    -5061.00790              16       0.8713
# 6N8T_41.pdb    -5150.02700              13       0.8758
# 6N8T_42.pdb    -5079.35590              16       0.8732
# 6N8T_43.pdb    -5336.91230              13       0.8756
# 6N8T_44.pdb    -5157.39465              26       0.8836
# 6N8T_45.pdb    -5584.05530              20       0.8785
# 6N8T_46.pdb    -5500.20400              14       0.8771
# 6N8T_47.pdb    -5098.86870              12       0.8773
# 6N8T_48.pdb    -5157.39200              16       0.8712
# 6N8T_49.pdb    -5414.87240               9       0.8761
# 6N8T_5.pdb     -5157.39465              26       0.8836
# 6N8T_50.pdb    -5157.39465              26       0.8836
# 6N8T_6.pdb     -5871.28170              15       0.8775
# 6N8T_7.pdb     -5868.90320              12       0.8765
# 6N8T_8.pdb     -4846.65070              12       0.8727
# 6N8T_9.pdb     -5052.49070              11       0.8780
#              HADDOCK-score  atomic-clashes  correlation
# structure
# 6N8Z_1.pdb     -4950.04400              13       0.9297
# 6N8Z_10.pdb    -5227.33260              10       0.9310
# 6N8Z_11.pdb    -5122.26490              13       0.9290
# 6N8Z_12.pdb    -4726.68860              12       0.9268
# 6N8Z_13.pdb    -4981.68800              10       0.9282
# 6R7I_19.pdb     -3607.9043              19       0.8807
# 6R7I_2.pdb      -3608.7070              19       0.8804
# 6R7I_20.pdb     -3657.2349              22       0.8837
# 6R7I_21.pdb     -3674.2753              18       0.8789
# 6R7I_22.pdb     -3502.1125              19       0.8815
# 6R7I_23.pdb     -3913.7030              20       0.8786
# 6R7I_24.pdb     -3830.5226              20       0.8854
# 6R7I_25.pdb     -3435.8347              20       0.8796
# 6R7I_26.pdb     -3611.3166              20       0.8829
# 6R7I_27.pdb     -3589.8610              22       0.8840
# 6R7I_28.pdb     -3771.2665              21       0.8835
# 6R7I_29.pdb     -3689.0657              18       0.8821
# 6R7I_3.pdb      -5176.4273               4       0.8803
# 6R7I_30.pdb     -4052.4757              20       0.8816
# 6R7I_31.pdb     -3697.0920              19       0.8815
# 6R7I_32.pdb     -3773.2975              22       0.8838
# 6R7I_33.pdb     -5237.0401               3       0.8810
# 6R7I_34.pdb     -3794.6646              21       0.8845
# 6R7I_35.pdb     -3509.4845              20       0.8809
# 6R7I_36.pdb     -3663.5380              17       0.8837
# 6R7I_37.pdb     -3560.3790              23       0.8802
# 6R7I_38.pdb     -3806.9506              23       0.8834
# 6R7I_39.pdb     -3911.3916              19       0.8830
# 6R7I_4.pdb      -3823.0529              21       0.8853
# 6R7I_40.pdb     -3567.9860              19       0.8843
# 6R7I_41.pdb     -3731.0493              21       0.8841
# 6R7I_42.pdb     -3923.4592              19       0.8851
# 6R7I_43.pdb     -3508.4760              20       0.8787
# 6R7I_44.pdb     -3639.6645              19       0.8834
# 6R7I_45.pdb     -3656.8660              20       0.8837
# 6R7I_46.pdb     -3625.8820              18       0.8852
# 6R7I_47.pdb     -3611.1820              20       0.8844
# 6R7I_48.pdb     -3767.1227              22       0.8825
# 6R7I_49.pdb     -3761.7650              21       0.8845
# 6R7I_5.pdb      -3478.7410              24       0.8831
# 6R7I_50.pdb     -3584.5424              20       0.8808
# 6R7I_6.pdb      -3646.2391              19       0.8825
# 6R7I_7.pdb      -4021.7738              19       0.8827
# 6R7I_8.pdb      -3792.1556              20       0.8802
# 6R7I_9.pdb      -3668.3350              20       0.8835

# %%
run_with_ambig_list = make_df_list("analysis_run-with-ambig")
# run_with_ambig_list[0].sort_values("HADDOCK-score")

analyzer = "atomic-clashes"
full_df = pd.DataFrame()
for run in range(len(run_with_ambig_list)):
    run_name = run_with_ambig_list[run].index[0][:4]
    if run_name in succes_list:
        no_em_top = run_with_ambig_list[run].sort_values("HADDOCK-score").reset_index()[:4][analyzer]
        no_em_top = no_em_top.rename("No EM map")
        #no_em_top = no_em_top.sub(ref_df.loc[run_name,analyzer])
        
        em_top = em_run_results[run].sort_values("HADDOCK-score").reset_index()[:4][analyzer]
        em_top = em_top.rename("With EM map")
        # = em_top.sub(ref_df.loc[run_name,analyzer])
           
        df = pd.DataFrame(no_em_top)
        df = pd.concat([df, pd.DataFrame(em_top)], axis = 1)
        full_df = pd.concat([full_df, df])
full_df = full_df.reset_index().drop("index", axis=1)
sns.boxplot(data=full_df)
plt.show()
